# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
starships_lst = []
for p in range(4):
    url = "https://swapi.dev/api/starships/?page="+str(p+1)
    response = requests.get(url).json()
    starships = response["results"]
    for starship in starships:
        starship["no_of_films"] = len(starship["films"])
        if len(starship["pilots"])>0:
            pilot_url = starship["pilots"][0]
            response = requests.get(pilot_url).json()
            starship["main_pilot"] = response["name"]
        else:
            starship["main_pilot"] = "No Pilot"
        starships_lst.append(starship)

# %%
starships_df = pd.DataFrame(starships_lst)
starships_df.T
target_cols = ["name", "manufacturer", "crew", "passengers", "cargo_capacity", "starship_class", "main_pilot"]
starships_df = starships_df[target_cols]
starships_df.replace("unknown",np.nan, inplace=True)
starships_df.dropna(inplace=True)
starships_df["cargo_capacity"].replace("none",0, inplace=True)
starships_df["crew"] = starships_df["crew"].str.replace(',','')
starships_df["passengers"] = starships_df["passengers"].str.replace(',','')
starships_df.loc[0,"crew"]=30
starships_df.loc[1,"passengers"]=0

# %%
starships_df["crew"] = starships_df['crew'].astype('int64')
starships_df["passengers"] = starships_df['passengers'].astype('int64')
starships_df["cargo_capacity"] = starships_df['cargo_capacity'].astype('int64')

# %%
starships_df["artifact"]="ss"
starships_df
# Out:
#                              name  \
# 0                   CR90 corvette
# 1                  Star Destroyer
# 2    Sentinel-class landing craft
# 3                      Death Star
# 4               Millennium Falcon
# 5                          Y-wing
# 6                          X-wing
# 7                 TIE Advanced x1
# 8                        Executor
# 9                 Rebel transport
# 10                        Slave 1
# 11               Imperial shuttle
# 12  EF76 Nebulon-B escort frigate
# 14                         A-wing
# 15                         B-wing
# 17             Droid control ship
# 18                  Naboo fighter
# 20                       Scimitar
# 23               Jedi starfighter
# 25          Republic Assault ship
# 26                   Solar Sailer
# 27       Trade Federation cruiser
# 28       Theta-class T-2c shuttle
# 29        Republic attack cruiser
# 31               Jedi Interceptor
# 32                        arc-170
# 34       Belbullab-22 starfighter
# 35                         V-wing
#
#                                          manufacturer    crew  passengers  \
# 0                   Corellian Engineering Corporation      30         600
# 1                                    Kuat Drive Yards   47060           0
# 2             Sienar Fleet Systems, Cyngus Spaceworks       5          75
# 3   Imperial Department of Military Research, Sien...  342953      843342
# 4                   Corellian Engineering Corporation       4           6
# 5                              Koensayr Manufacturing       2           0
# 6                                   Incom Corporation       1           0
# 7                                Sienar Fleet Systems       1           0
# 8                  Kuat Drive Yards, Fondor Shipyards  279144       38000
# 9                               Gallofree Yards, Inc.       6          90
# 10                           Kuat Systems Engineering       1           6
# 11                               Sienar Fleet Systems       6          20
# 12                                   Kuat Drive Yards     854          75
# 14  Alliance Underground Engineering, Incom Corpor...       1           0
# 15                                     Slayn & Korpil       1           0
# 17                         Hoersch-Kessel Drive, Inc.     175      139000
# 18        Theed Palace Space Vessel Engineering Corps       1           0
# 20                            Republic Sienar Systems       1           6
# 23                           Kuat Systems Engineering       1           0
# 25                          Rothana Heavy Engineering     700       16000
# 26            Huppla Pasa Tisc Shipwrights Collective       3          11
# 27  Rendili StarDrive, Free Dac Volunteers Enginee...     600       48247
# 28                                  Cygnus Spaceworks       5          16
# 29          Kuat Drive Yards, Allanteen Six shipyards    7400        2000
# 31                           Kuat Systems Engineering       1           0
# 32              Incom Corporation, Subpro Corporation       3           0
# 34                 Feethan Ottraw Scalable Assemblies       1           0
# 35                           Kuat Systems Engineering       1           0
#
#     cargo_capacity                   starship_class        main_pilot artifact
# 0          3000000                         corvette          No Pilot       ss
# 1         36000000                   Star Destroyer          No Pilot       ss
# 2           180000                    landing craft          No Pilot       ss
# 3    1000000000000  Deep Space Mobile Battlestation          No Pilot       ss
# 4           100000                  Light freighter         Chewbacca       ss
# 5              110              assault starfighter          No Pilot       ss
# 6              110                      Starfighter    Luke Skywalker       ss
# 7              150                      Starfighter       Darth Vader       ss
# 8        250000000                 Star dreadnought          No Pilot       ss
# 9         19000000                 Medium transport          No Pilot       ss
# 10           70000                     Patrol craft         Boba Fett       ss
# 11           80000       Armed government transport    Luke Skywalker       ss
# 12         6000000                      Escort ship          No Pilot       ss
# 14              40                      Starfighter      Arvel Crynyd       ss
# 15              45              Assault Starfighter          No Pilot       ss
# 17      4000000000               Droid control ship          No Pilot       ss
# 18              65                      Starfighter  Anakin Skywalker       ss
# 20         2500000                  Space Transport        Darth Maul       ss
# 23              60                      Starfighter    Obi-Wan Kenobi       ss
# 25        11250000                     assault ship          No Pilot       ss
# 26             240                            yacht          No Pilot       ss
# 27        50000000                     capital ship    Obi-Wan Kenobi       ss
# 28           50000                        transport          No Pilot       ss
# 29        20000000                   star destroyer          No Pilot       ss
# 31              60                      starfighter    Obi-Wan Kenobi       ss
# 32             110                      starfighter          No Pilot       ss
# 34             140                      starfighter    Obi-Wan Kenobi       ss
# 35              60                      starfighter          No Pilot       ss

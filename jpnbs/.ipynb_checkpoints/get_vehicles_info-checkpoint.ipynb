# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
vehicles_lst = []
for p in range(4):
    url = "https://swapi.dev/api/vehicles/?page="+str(p+1)
    response = requests.get(url).json()
    vehicles = response["results"]
    for vehicle in vehicles:
        vehicle["no_of_films"] = len(vehicle["films"])
        if len(vehicle["pilots"])>0:
            pilot_url = vehicle["pilots"][0]
            response = requests.get(pilot_url).json()
            vehicle["main_pilot"] = response["name"]
        else:
            vehicle["main_pilot"] = "No Pilot"
        vehicles_lst.append(vehicle)

# %%
vehicles_df = pd.DataFrame(vehicles_lst)
vehicles_df.T
target_cols = ["name", "manufacturer", "crew", "passengers", "cargo_capacity", "vehicle_class", "main_pilot","no_of_films"]
vehicles_df = vehicles_df[target_cols]
vehicles_df.replace("unknown",np.nan, inplace=True)
vehicles_df.dropna(inplace=True)
vehicles_df["cargo_capacity"].replace("none",0, inplace=True)

# %%
vehicles_df["crew"] = vehicles_df['crew'].astype('int64')
vehicles_df["passengers"] = vehicles_df['passengers'].astype('int64')
vehicles_df["cargo_capacity"] = vehicles_df['cargo_capacity'].astype('int64')

# %%
vehicles_df["artifact"]="ve"
vehicles_df.reset_index()
vehicles_df
# Out:
#                               name  \
# 0                     Sand Crawler
# 1                   T-16 skyhopper
# 2                 X-34 landspeeder
# 3               TIE/LN starfighter
# 4                      Snowspeeder
# 5                       TIE bomber
# 6                            AT-AT
# 7                            AT-ST
# 8      Storm IV Twin-Pod cloud car
# 9                       Sail barge
# 10           Bantha-II cargo skiff
# 11              TIE/IN interceptor
# 12           Imperial Speeder Bike
# 13                   Vulture Droid
# 14           Multi-Troop Transport
# 16  Single Trooper Aerial Platform
# 17            C-9979 landing craft
# 18                 Tribubble bongo
# 19                    Sith speeder
# 20             Zephyr-G swoop bike
# 21      Koro-2 Exodrive airspeeder
# 23                          LAAT/i
# 24                          LAAT/c
# 25                           AT-TE
# 26                            SPHA
# 28              Neimoidian shuttle
# 30     Tsmeu-6 personal wheel bike
# 32               Droid tri-fighter
# 33           Oevvaor jet catamaran
# 34     Raddaugh Gnasp fluttercraft
# 35                Clone turbo tank
# 36   Corporate Alliance tank droid
# 37                   Droid gunship
# 38                           AT-RT
#
#                                          manufacturer  crew  passengers  \
# 0                         Corellia Mining Corporation    46          30
# 1                                   Incom Corporation     1           1
# 2                                SoroSuub Corporation     1           1
# 3                                Sienar Fleet Systems     1           0
# 4                                   Incom corporation     2           0
# 5                                Sienar Fleet Systems     1           0
# 6   Kuat Drive Yards, Imperial Department of Milit...     5          40
# 7   Kuat Drive Yards, Imperial Department of Milit...     2           0
# 8                                       Bespin Motors     2           0
# 9        Ubrikkian Industries Custom Vehicle Division    26         500
# 10                               Ubrikkian Industries     5          16
# 11                               Sienar Fleet Systems     1           0
# 12                           Aratech Repulsor Company     1           1
# 13     Haor Chall Engineering, Baktoid Armor Workshop     0           0
# 14                             Baktoid Armor Workshop     4         112
# 16                             Baktoid Armor Workshop     1           0
# 17                             Haor Chall Engineering   140         284
# 18                  Otoh Gunga Bongameken Cooperative     1           2
# 19                                            Razalon     1           0
# 20                        Mobquet Swoops and Speeders     1           1
# 21          Desler Gizh Outworld Mobility Corporation     1           1
# 23                          Rothana Heavy Engineering     6          30
# 24                          Rothana Heavy Engineering     1           0
# 25        Rothana Heavy Engineering, Kuat Drive Yards     6          36
# 26                          Rothana Heavy Engineering    25          30
# 28                             Haor Chall Engineering     2           6
# 30               Z-Gomot Ternbuell Guppat Corporation     1           1
# 32   Colla Designs, Phlac-Arphocc Automata Industries     1           0
# 33                        Appazanna Engineering Works     2           2
# 34                        Appazanna Engineering Works     2           0
# 35                                   Kuat Drive Yards    20         300
# 36                                       Techno Union     0           4
# 37     Baktoid Fleet Ordnance, Haor Chall Engineering     0           0
# 38                                   Kuat Drive Yards     1           0
#
#     cargo_capacity              vehicle_class        main_pilot artifact
# 0            50000                    wheeled          No Pilot       ss
# 1               50              repulsorcraft          No Pilot       ss
# 2                5              repulsorcraft          No Pilot       ss
# 3               65                starfighter          No Pilot       ss
# 4               10                 airspeeder    Luke Skywalker       ss
# 5                0     space/planetary bomber          No Pilot       ss
# 6             1000             assault walker          No Pilot       ss
# 7              200                     walker         Chewbacca       ss
# 8               10              repulsorcraft          No Pilot       ss
# 9          2000000                 sail barge          No Pilot       ss
# 10          135000  repulsorcraft cargo skiff          No Pilot       ss
# 11              75                starfighter          No Pilot       ss
# 12               4                    speeder    Luke Skywalker       ss
# 13               0                starfighter          No Pilot       ss
# 14           12000              repulsorcraft          No Pilot       ss
# 16               0              repulsorcraft          No Pilot       ss
# 17         1800000              landing craft          No Pilot       ss
# 18            1600                  submarine    Obi-Wan Kenobi       ss
# 19               2                    speeder        Darth Maul       ss
# 20             200              repulsorcraft  Anakin Skywalker       ss
# 21              80                 airspeeder        Zam Wesell       ss
# 23             170                    gunship          No Pilot       ss
# 24           40000                    gunship          No Pilot       ss
# 25           10000                     walker          No Pilot       ss
# 26             500                     walker          No Pilot       ss
# 28            1000                  transport          No Pilot       ss
# 30              10             wheeled walker          Grievous       ss
# 32               0          droid starfighter          No Pilot       ss
# 33              50                 airspeeder          No Pilot       ss
# 34              20                air speeder          No Pilot       ss
# 35           30000             wheeled walker          No Pilot       ss
# 36               0                 droid tank          No Pilot       ss
# 37               0                 airspeeder          No Pilot       ss
# 38              20                     walker          No Pilot       ss
